# %% [markdown]
# # Building Travel Freedom
#
# Learned scraping for other places now need to piece it together

# %%
# importing the neccessary dependancies

import bs4 as bs #importing beautiful script
import urllib.request # to request a url
import time
import requests
import pandas as pd

# might not need these:
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/ashwinmanghat/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ## Scrape function
#
# fetch_results() - gets the urls of the search results.
#
# i/p - keyword, no. of results. and language

# %%
USER_AGENT = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}

# fetch google search results

def fetch_results(search_term, number_results, language_code):
    assert isinstance(search_term, str), 'Search term must be a string'
    assert isinstance(number_results, int), 'Number of results must be an integer'
    escaped_search_term = search_term.replace(' ', '+')
 
    google_url = 'https://www.google.com/search?q={}&num={}&hl={}'.format(escaped_search_term, number_results, language_code)
    response = requests.get(google_url, headers=USER_AGENT)
    response.raise_for_status()
 
    return search_term, response.text

# %% [markdown]
# ## Parsing the results
#
# Parse the results to a table/list based on what data is being pulled out.

# %%
#Parsed results

def parse_results(html, keyword):
    soup = bs.BeautifulSoup(html, 'html.parser')
    found_results = []
    rank = 1
    result_block = soup.find_all('div', attrs={'class': 'g'})
    for result in result_block:

        link = result.find('a', href=True)
        title = result.find('h3', attrs={'class': 'r'})
        description = result.find('span', attrs={'class': 'st'})
        if link and title:
            link = link['href']
            title = title.get_text()
            if description:
                description = description.get_text()
            if link != '#':
                found_results.append({'keyword': keyword, 'rank': rank, 'title': title, 'description': description, 'link':link})
#                 print({'keyword': keyword, 'rank': rank, 'title': title, 'description': description})
                rank += 1
                links.append(link)
    return(found_results)

# %% [markdown]
# ## Main function

# %%
def scrape_google(search_term, number_results, language_code):
    try:
        keyword, html = fetch_results(search_term, number_results, language_code)
        results = parse_results(html, keyword)
        return results
    except AssertionError:
        raise Exception("Incorrect arguments parsed to function")
    except requests.HTTPError:
        raise Exception("You appear to have been blocked by Google")
    except requests.RequestException:
        raise Exception("Appears to be an issue with your connection")


if __name__ == '__main__':
#     keywords = ['edmund martin', 'python', 'google scraping']
    destination = input('What is your destination?')
    x = destination
    links =[]
    keywords = [x+" tourism", x+" travel", x+" vaccation"]
    data = []
    for keyword in keywords:
        try:
            results = scrape_google(keyword, 10, "en")
            for result in results:
                data.append(result)
                #print(results)
        except Exception as e:
            print(e)
        finally:
            time.sleep(1)
# Out:
# What is your destination?vietnam
# [{'keyword': 'vietnam tourism', 'rank': 1, 'title': 'Vietnam/Popular destinations', 'description': None, 'link': '/destination?q=vietnam+tourism&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwjK8PqP14DaAhWBNo8KHUwfAeMQ7NEBCCwoADAA'}, {'keyword': 'vietnam tourism', 'rank': 2, 'title': 'Vietnam/Popular destinations', 'description': None, 'link': '/destination?q=vietnam+tourism&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwjK8PqP14DaAhWBNo8KHUwfAeMQ7NEBCCwoADAA'}, {'keyword': 'vietnam tourism', 'rank': 3, 'title': 'VIETNAM NATIONAL ADMINISTRATION OF TOURISM', 'description': 'Tong cuc Du lich Viet Nam - Thong tin tong hop - Van ban quan ly nha nuoc.', 'link': 'http://www.vietnamtourism.com/'}, {'keyword': 'vietnam tourism', 'rank': 4, 'title': 'Vietnam 2018: Best of Vietnam Tourism - TripAdvisor', 'description': 'Vietnam Tourism: TripAdvisor has 2329025 reviews of Vietnam Hotels, Attractions, and Restaurants making it your best Vietnam resource.', 'link': 'https://www.tripadvisor.com/Tourism-g293921-Vietnam-Vacations.html'}, {'keyword': 'vietnam tourism', 'rank': 5, 'title': 'Vietnam Tourism, Tourist Places Vietnam, Vietnam Tourism Packages', 'description': 'Vietnam Tourism - Information about tourist places in Vietnam, events & activities, map, attractions in Vietnam. Book Vietnam tourism packages at MakeMyTrip.com.', 'link': 'https://www.makemytrip.com/holidays-international/vietnam-tourism.html'}, {'keyword': 'vietnam tourism', 'rank': 6, 'title': 'Vietnam Tourism (2018): Best of Vietnam - TripAdvisor', 'description': 'Vietnam Tourism: TripAdvisor has 23,29025 reviews of Vietnam Hotels, Attractions, and Restaurants making it your best Vietnam Tourism resource.', 'link': 'https://www.tripadvisor.in/Tourism-g293921-Vietnam-Vacations.html'}, {'keyword': 'vietnam tourism', 'rank': 7, 'title': 'Tourism in Vietnam - Wikipedia', 'description': 'Tourism in Vietnam is a component of the modern Vietnamese economy. In 2012, Vietnam received more than 6.8 million international arrivals, up from 2.1 million in the year 2000. The annual increase represented a rebound from a decline in 2008 Great Recession. The Vietnam National Administration of Tourism is\xa0...', 'link': 'https://en.wikipedia.org/wiki/Tourism_in_Vietnam'}, {'keyword': 'vietnam tourism', 'rank': 8, 'title': 'Vietnam Tourism, Tourist Places in Vietnam, Vietnam Tour and Travel ...', 'description': 'Vietnam Tourism - Get complete information about popular tourist destinations in Vietnam, must visit places in Vietnam, Vietnam tourism packages, best time to visit, map, events, Vietnam culture and food, best attractions in Vietnam, activities and nightlife in Vietnam.', 'link': 'https://www.yatra.com/international-tourism/vietnam'}, {'keyword': 'vietnam tourism', 'rank': 9, 'title': 'Vietnam Tourism > Travel Guide, Places to visit, Tours and Packages', 'description': 'Get the best Information about Vietnam Tourism. Get travel guides and plan your trip to Vietnam with places to visit, sightseeing, hotels, and reviews by other travellers.', 'link': 'https://www.holidify.com/country/vietnam/'}, {'keyword': 'vietnam tourism', 'rank': 10, 'title': 'Vietnam travel - Lonely Planet', 'description': 'Explore Vietnam holidays and discover the best time and places to visit. | A land of staggering natural beauty and cultural complexities, of dynamic megacities and hill-tribe villages, Vietnam is both exotic and compelling.', 'link': 'https://www.lonelyplanet.com/vietnam'}, {'keyword': 'vietnam tourism', 'rank': 11, 'title': 'Vietnam - Amazing destination, Vietnam Tours 2015 - 2016, Vietnam ...', 'description': 'Discover Amazing Vietnam with TripAsean Tour, please visit our web: http://tripasean.com/ to get more ...', 'link': 'https://www.youtube.com/watch?v=R-M3gXY_Hds'}]
# [{'keyword': 'vietnam tourism', 'rank': 1, 'title': 'Vietnam/Popular destinations', 'description': None, 'link': '/destination?q=vietnam+tourism&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwjK8PqP14DaAhWBNo8KHUwfAeMQ7NEBCCwoADAA'}, {'keyword': 'vietnam tourism', 'rank': 2, 'title': 'Vietnam/Popular destinations', 'description': None, 'link': '/destination?q=vietnam+tourism&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwjK8PqP14DaAhWBNo8KHUwfAeMQ7NEBCCwoADAA'}, {'keyword': 'vietnam tourism', 'rank': 3, 'title': 'VIETNAM NATIONAL ADMINISTRATION OF TOURISM', 'description': 'Tong cuc Du lich Viet Nam - Thong tin tong hop - Van ban quan ly nha nuoc.', 'link': 'http://www.vietnamtourism.com/'}, {'keyword': 'vietnam tourism', 'rank': 4, 'title': 'Vietnam 2018: Best of Vietnam Tourism - TripAdvisor', 'description': 'Vietnam Tourism: TripAdvisor has 2329025 reviews of Vietnam Hotels, Attractions, and Restaurants making it your best Vietnam resource.', 'link': 'https://www.tripadvisor.com/Tourism-g293921-Vietnam-Vacations.html'}, {'keyword': 'vietnam tourism', 'rank': 5, 'title': 'Vietnam Tourism, Tourist Places Vietnam, Vietnam Tourism Packages', 'description': 'Vietnam Tourism - Information about tourist places in Vietnam, events & activities, map, attractions in Vietnam. Book Vietnam tourism packages at MakeMyTrip.com.', 'link': 'https://www.makemytrip.com/holidays-international/vietnam-tourism.html'}, {'keyword': 'vietnam tourism', 'rank': 6, 'title': 'Vietnam Tourism (2018): Best of Vietnam - TripAdvisor', 'description': 'Vietnam Tourism: TripAdvisor has 23,29025 reviews of Vietnam Hotels, Attractions, and Restaurants making it your best Vietnam Tourism resource.', 'link': 'https://www.tripadvisor.in/Tourism-g293921-Vietnam-Vacations.html'}, {'keyword': 'vietnam tourism', 'rank': 7, 'title': 'Tourism in Vietnam - Wikipedia', 'description': 'Tourism in Vietnam is a component of the modern Vietnamese economy. In 2012, Vietnam received more than 6.8 million international arrivals, up from 2.1 million in the year 2000. The annual increase represented a rebound from a decline in 2008 Great Recession. The Vietnam National Administration of Tourism is\xa0...', 'link': 'https://en.wikipedia.org/wiki/Tourism_in_Vietnam'}, {'keyword': 'vietnam tourism', 'rank': 8, 'title': 'Vietnam Tourism, Tourist Places in Vietnam, Vietnam Tour and Travel ...', 'description': 'Vietnam Tourism - Get complete information about popular tourist destinations in Vietnam, must visit places in Vietnam, Vietnam tourism packages, best time to visit, map, events, Vietnam culture and food, best attractions in Vietnam, activities and nightlife in Vietnam.', 'link': 'https://www.yatra.com/international-tourism/vietnam'}, {'keyword': 'vietnam tourism', 'rank': 9, 'title': 'Vietnam Tourism > Travel Guide, Places to visit, Tours and Packages', 'description': 'Get the best Information about Vietnam Tourism. Get travel guides and plan your trip to Vietnam with places to visit, sightseeing, hotels, and reviews by other travellers.', 'link': 'https://www.holidify.com/country/vietnam/'}, {'keyword': 'vietnam tourism', 'rank': 10, 'title': 'Vietnam travel - Lonely Planet', 'description': 'Explore Vietnam holidays and discover the best time and places to visit. | A land of staggering natural beauty and cultural complexities, of dynamic megacities and hill-tribe villages, Vietnam is both exotic and compelling.', 'link': 'https://www.lonelyplanet.com/vietnam'}, {'keyword': 'vietnam tourism', 'rank': 11, 'title': 'Vietnam - Amazing destination, Vietnam Tours 2015 - 2016, Vietnam ...', 'description': 'Discover Amazing Vietnam with TripAsean Tour, please visit our web: http://tripasean.com/ to get more ...', 'link': 'https://www.youtube.com/watch?v=R-M3gXY_Hds'}]
# [{'keyword': 'vietnam tourism', 'rank': 1, 'title': 'Vietnam/Popular destinations', 'description': None, 'link': '/destination?q=vietnam+tourism&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwjK8PqP14DaAhWBNo8KHUwfAeMQ7NEBCCwoADAA'}, {'keyword': 'vietnam tourism', 'rank': 2, 'title': 'Vietnam/Popular destinations', 'description': None, 'link': '/destination?q=vietnam+tourism&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwjK8PqP14DaAhWBNo8KHUwfAeMQ7NEBCCwoADAA'}, {'keyword': 'vietnam tourism', 'rank': 3, 'title': 'VIETNAM NATIONAL ADMINISTRATION OF TOURISM', 'description': 'Tong cuc Du lich Viet Nam - Thong tin tong hop - Van ban quan ly nha nuoc.', 'link': 'http://www.vietnamtourism.com/'}, {'keyword': 'vietnam tourism', 'rank': 4, 'title': 'Vietnam 2018: Best of Vietnam Tourism - TripAdvisor', 'description': 'Vietnam Tourism: TripAdvisor has 2329025 reviews of Vietnam Hotels, Attractions, and Restaurants making it your best Vietnam resource.', 'link': 'https://www.tripadvisor.com/Tourism-g293921-Vietnam-Vacations.html'}, {'keyword': 'vietnam tourism', 'rank': 5, 'title': 'Vietnam Tourism, Tourist Places Vietnam, Vietnam Tourism Packages', 'description': 'Vietnam Tourism - Information about tourist places in Vietnam, events & activities, map, attractions in Vietnam. Book Vietnam tourism packages at MakeMyTrip.com.', 'link': 'https://www.makemytrip.com/holidays-international/vietnam-tourism.html'}, {'keyword': 'vietnam tourism', 'rank': 6, 'title': 'Vietnam Tourism (2018): Best of Vietnam - TripAdvisor', 'description': 'Vietnam Tourism: TripAdvisor has 23,29025 reviews of Vietnam Hotels, Attractions, and Restaurants making it your best Vietnam Tourism resource.', 'link': 'https://www.tripadvisor.in/Tourism-g293921-Vietnam-Vacations.html'}, {'keyword': 'vietnam tourism', 'rank': 7, 'title': 'Tourism in Vietnam - Wikipedia', 'description': 'Tourism in Vietnam is a component of the modern Vietnamese economy. In 2012, Vietnam received more than 6.8 million international arrivals, up from 2.1 million in the year 2000. The annual increase represented a rebound from a decline in 2008 Great Recession. The Vietnam National Administration of Tourism is\xa0...', 'link': 'https://en.wikipedia.org/wiki/Tourism_in_Vietnam'}, {'keyword': 'vietnam tourism', 'rank': 8, 'title': 'Vietnam Tourism, Tourist Places in Vietnam, Vietnam Tour and Travel ...', 'description': 'Vietnam Tourism - Get complete information about popular tourist destinations in Vietnam, must visit places in Vietnam, Vietnam tourism packages, best time to visit, map, events, Vietnam culture and food, best attractions in Vietnam, activities and nightlife in Vietnam.', 'link': 'https://www.yatra.com/international-tourism/vietnam'}, {'keyword': 'vietnam tourism', 'rank': 9, 'title': 'Vietnam Tourism > Travel Guide, Places to visit, Tours and Packages', 'description': 'Get the best Information about Vietnam Tourism. Get travel guides and plan your trip to Vietnam with places to visit, sightseeing, hotels, and reviews by other travellers.', 'link': 'https://www.holidify.com/country/vietnam/'}, {'keyword': 'vietnam tourism', 'rank': 10, 'title': 'Vietnam travel - Lonely Planet', 'description': 'Explore Vietnam holidays and discover the best time and places to visit. | A land of staggering natural beauty and cultural complexities, of dynamic megacities and hill-tribe villages, Vietnam is both exotic and compelling.', 'link': 'https://www.lonelyplanet.com/vietnam'}, {'keyword': 'vietnam tourism', 'rank': 11, 'title': 'Vietnam - Amazing destination, Vietnam Tours 2015 - 2016, Vietnam ...', 'description': 'Discover Amazing Vietnam with TripAsean Tour, please visit our web: http://tripasean.com/ to get more ...', 'link': 'https://www.youtube.com/watch?v=R-M3gXY_Hds'}]
# [{'keyword': 'vietnam tourism', 'rank': 1, 'title': 'Vietnam/Popular destinations', 'description': None, 'link': '/destination?q=vietnam+tourism&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwjK8PqP14DaAhWBNo8KHUwfAeMQ7NEBCCwoADAA'}, {'keyword': 'vietnam tourism', 'rank': 2, 'title': 'Vietnam/Popular destinations', 'description': None, 'link': '/destination?q=vietnam+tourism&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwjK8PqP14DaAhWBNo8KHUwfAeMQ7NEBCCwoADAA'}, {'keyword': 'vietnam tourism', 'rank': 3, 'title': 'VIETNAM NATIONAL ADMINISTRATION OF TOURISM', 'description': 'Tong cuc Du lich Viet Nam - Thong tin tong hop - Van ban quan ly nha nuoc.', 'link': 'http://www.vietnamtourism.com/'}, {'keyword': 'vietnam tourism', 'rank': 4, 'title': 'Vietnam 2018: Best of Vietnam Tourism - TripAdvisor', 'description': 'Vietnam Tourism: TripAdvisor has 2329025 reviews of Vietnam Hotels, Attractions, and Restaurants making it your best Vietnam resource.', 'link': 'https://www.tripadvisor.com/Tourism-g293921-Vietnam-Vacations.html'}, {'keyword': 'vietnam tourism', 'rank': 5, 'title': 'Vietnam Tourism, Tourist Places Vietnam, Vietnam Tourism Packages', 'description': 'Vietnam Tourism - Information about tourist places in Vietnam, events & activities, map, attractions in Vietnam. Book Vietnam tourism packages at MakeMyTrip.com.', 'link': 'https://www.makemytrip.com/holidays-international/vietnam-tourism.html'}, {'keyword': 'vietnam tourism', 'rank': 6, 'title': 'Vietnam Tourism (2018): Best of Vietnam - TripAdvisor', 'description': 'Vietnam Tourism: TripAdvisor has 23,29025 reviews of Vietnam Hotels, Attractions, and Restaurants making it your best Vietnam Tourism resource.', 'link': 'https://www.tripadvisor.in/Tourism-g293921-Vietnam-Vacations.html'}, {'keyword': 'vietnam tourism', 'rank': 7, 'title': 'Tourism in Vietnam - Wikipedia', 'description': 'Tourism in Vietnam is a component of the modern Vietnamese economy. In 2012, Vietnam received more than 6.8 million international arrivals, up from 2.1 million in the year 2000. The annual increase represented a rebound from a decline in 2008 Great Recession. The Vietnam National Administration of Tourism is\xa0...', 'link': 'https://en.wikipedia.org/wiki/Tourism_in_Vietnam'}, {'keyword': 'vietnam tourism', 'rank': 8, 'title': 'Vietnam Tourism, Tourist Places in Vietnam, Vietnam Tour and Travel ...', 'description': 'Vietnam Tourism - Get complete information about popular tourist destinations in Vietnam, must visit places in Vietnam, Vietnam tourism packages, best time to visit, map, events, Vietnam culture and food, best attractions in Vietnam, activities and nightlife in Vietnam.', 'link': 'https://www.yatra.com/international-tourism/vietnam'}, {'keyword': 'vietnam tourism', 'rank': 9, 'title': 'Vietnam Tourism > Travel Guide, Places to visit, Tours and Packages', 'description': 'Get the best Information about Vietnam Tourism. Get travel guides and plan your trip to Vietnam with places to visit, sightseeing, hotels, and reviews by other travellers.', 'link': 'https://www.holidify.com/country/vietnam/'}, {'keyword': 'vietnam tourism', 'rank': 10, 'title': 'Vietnam travel - Lonely Planet', 'description': 'Explore Vietnam holidays and discover the best time and places to visit. | A land of staggering natural beauty and cultural complexities, of dynamic megacities and hill-tribe villages, Vietnam is both exotic and compelling.', 'link': 'https://www.lonelyplanet.com/vietnam'}, {'keyword': 'vietnam tourism', 'rank': 11, 'title': 'Vietnam - Amazing destination, Vietnam Tours 2015 - 2016, Vietnam ...', 'description': 'Discover Amazing Vietnam with TripAsean Tour, please visit our web: http://tripasean.com/ to get more ...', 'link': 'https://www.youtube.com/watch?v=R-M3gXY_Hds'}]
# [{'keyword': 'vietnam tourism', 'rank': 1, 'title': 'Vietnam/Popular destinations', 'description': None, 'link': '/destination?q=vietnam+tourism&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwjK8PqP14DaAhWBNo8KHUwfAeMQ7NEBCCwoADAA'}, {'keyword': 'vietnam tourism', 'rank': 2, 'title': 'Vietnam/Popular destinations', 'description': None, 'link': '/destination?q=vietnam+tourism&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwjK8PqP14DaAhWBNo8KHUwfAeMQ7NEBCCwoADAA'}, {'keyword': 'vietnam tourism', 'rank': 3, 'title': 'VIETNAM NATIONAL ADMINISTRATION OF TOURISM', 'description': 'Tong cuc Du lich Viet Nam - Thong tin tong hop - Van ban quan ly nha nuoc.', 'link': 'http://www.vietnamtourism.com/'}, {'keyword': 'vietnam tourism', 'rank': 4, 'title': 'Vietnam 2018: Best of Vietnam Tourism - TripAdvisor', 'description': 'Vietnam Tourism: TripAdvisor has 2329025 reviews of Vietnam Hotels, Attractions, and Restaurants making it your best Vietnam resource.', 'link': 'https://www.tripadvisor.com/Tourism-g293921-Vietnam-Vacations.html'}, {'keyword': 'vietnam tourism', 'rank': 5, 'title': 'Vietnam Tourism, Tourist Places Vietnam, Vietnam Tourism Packages', 'description': 'Vietnam Tourism - Information about tourist places in Vietnam, events & activities, map, attractions in Vietnam. Book Vietnam tourism packages at MakeMyTrip.com.', 'link': 'https://www.makemytrip.com/holidays-international/vietnam-tourism.html'}, {'keyword': 'vietnam tourism', 'rank': 6, 'title': 'Vietnam Tourism (2018): Best of Vietnam - TripAdvisor', 'description': 'Vietnam Tourism: TripAdvisor has 23,29025 reviews of Vietnam Hotels, Attractions, and Restaurants making it your best Vietnam Tourism resource.', 'link': 'https://www.tripadvisor.in/Tourism-g293921-Vietnam-Vacations.html'}, {'keyword': 'vietnam tourism', 'rank': 7, 'title': 'Tourism in Vietnam - Wikipedia', 'description': 'Tourism in Vietnam is a component of the modern Vietnamese economy. In 2012, Vietnam received more than 6.8 million international arrivals, up from 2.1 million in the year 2000. The annual increase represented a rebound from a decline in 2008 Great Recession. The Vietnam National Administration of Tourism is\xa0...', 'link': 'https://en.wikipedia.org/wiki/Tourism_in_Vietnam'}, {'keyword': 'vietnam tourism', 'rank': 8, 'title': 'Vietnam Tourism, Tourist Places in Vietnam, Vietnam Tour and Travel ...', 'description': 'Vietnam Tourism - Get complete information about popular tourist destinations in Vietnam, must visit places in Vietnam, Vietnam tourism packages, best time to visit, map, events, Vietnam culture and food, best attractions in Vietnam, activities and nightlife in Vietnam.', 'link': 'https://www.yatra.com/international-tourism/vietnam'}, {'keyword': 'vietnam tourism', 'rank': 9, 'title': 'Vietnam Tourism > Travel Guide, Places to visit, Tours and Packages', 'description': 'Get the best Information about Vietnam Tourism. Get travel guides and plan your trip to Vietnam with places to visit, sightseeing, hotels, and reviews by other travellers.', 'link': 'https://www.holidify.com/country/vietnam/'}, {'keyword': 'vietnam tourism', 'rank': 10, 'title': 'Vietnam travel - Lonely Planet', 'description': 'Explore Vietnam holidays and discover the best time and places to visit. | A land of staggering natural beauty and cultural complexities, of dynamic megacities and hill-tribe villages, Vietnam is both exotic and compelling.', 'link': 'https://www.lonelyplanet.com/vietnam'}, {'keyword': 'vietnam tourism', 'rank': 11, 'title': 'Vietnam - Amazing destination, Vietnam Tours 2015 - 2016, Vietnam ...', 'description': 'Discover Amazing Vietnam with TripAsean Tour, please visit our web: http://tripasean.com/ to get more ...', 'link': 'https://www.youtube.com/watch?v=R-M3gXY_Hds'}]
# [{'keyword': 'vietnam tourism', 'rank': 1, 'title': 'Vietnam/Popular destinations', 'description': None, 'link': '/destination?q=vietnam+tourism&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwjK8PqP14DaAhWBNo8KHUwfAeMQ7NEBCCwoADAA'}, {'keyword': 'vietnam tourism', 'rank': 2, 'title': 'Vietnam/Popular destinations', 'description': None, 'link': '/destination?q=vietnam+tourism&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwjK8PqP14DaAhWBNo8KHUwfAeMQ7NEBCCwoADAA'}, {'keyword': 'vietnam tourism', 'rank': 3, 'title': 'VIETNAM NATIONAL ADMINISTRATION OF TOURISM', 'description': 'Tong cuc Du lich Viet Nam - Thong tin tong hop - Van ban quan ly nha nuoc.', 'link': 'http://www.vietnamtourism.com/'}, {'keyword': 'vietnam tourism', 'rank': 4, 'title': 'Vietnam 2018: Best of Vietnam Tourism - TripAdvisor', 'description': 'Vietnam Tourism: TripAdvisor has 2329025 reviews of Vietnam Hotels, Attractions, and Restaurants making it your best Vietnam resource.', 'link': 'https://www.tripadvisor.com/Tourism-g293921-Vietnam-Vacations.html'}, {'keyword': 'vietnam tourism', 'rank': 5, 'title': 'Vietnam Tourism, Tourist Places Vietnam, Vietnam Tourism Packages', 'description': 'Vietnam Tourism - Information about tourist places in Vietnam, events & activities, map, attractions in Vietnam. Book Vietnam tourism packages at MakeMyTrip.com.', 'link': 'https://www.makemytrip.com/holidays-international/vietnam-tourism.html'}, {'keyword': 'vietnam tourism', 'rank': 6, 'title': 'Vietnam Tourism (2018): Best of Vietnam - TripAdvisor', 'description': 'Vietnam Tourism: TripAdvisor has 23,29025 reviews of Vietnam Hotels, Attractions, and Restaurants making it your best Vietnam Tourism resource.', 'link': 'https://www.tripadvisor.in/Tourism-g293921-Vietnam-Vacations.html'}, {'keyword': 'vietnam tourism', 'rank': 7, 'title': 'Tourism in Vietnam - Wikipedia', 'description': 'Tourism in Vietnam is a component of the modern Vietnamese economy. In 2012, Vietnam received more than 6.8 million international arrivals, up from 2.1 million in the year 2000. The annual increase represented a rebound from a decline in 2008 Great Recession. The Vietnam National Administration of Tourism is\xa0...', 'link': 'https://en.wikipedia.org/wiki/Tourism_in_Vietnam'}, {'keyword': 'vietnam tourism', 'rank': 8, 'title': 'Vietnam Tourism, Tourist Places in Vietnam, Vietnam Tour and Travel ...', 'description': 'Vietnam Tourism - Get complete information about popular tourist destinations in Vietnam, must visit places in Vietnam, Vietnam tourism packages, best time to visit, map, events, Vietnam culture and food, best attractions in Vietnam, activities and nightlife in Vietnam.', 'link': 'https://www.yatra.com/international-tourism/vietnam'}, {'keyword': 'vietnam tourism', 'rank': 9, 'title': 'Vietnam Tourism > Travel Guide, Places to visit, Tours and Packages', 'description': 'Get the best Information about Vietnam Tourism. Get travel guides and plan your trip to Vietnam with places to visit, sightseeing, hotels, and reviews by other travellers.', 'link': 'https://www.holidify.com/country/vietnam/'}, {'keyword': 'vietnam tourism', 'rank': 10, 'title': 'Vietnam travel - Lonely Planet', 'description': 'Explore Vietnam holidays and discover the best time and places to visit. | A land of staggering natural beauty and cultural complexities, of dynamic megacities and hill-tribe villages, Vietnam is both exotic and compelling.', 'link': 'https://www.lonelyplanet.com/vietnam'}, {'keyword': 'vietnam tourism', 'rank': 11, 'title': 'Vietnam - Amazing destination, Vietnam Tours 2015 - 2016, Vietnam ...', 'description': 'Discover Amazing Vietnam with TripAsean Tour, please visit our web: http://tripasean.com/ to get more ...', 'link': 'https://www.youtube.com/watch?v=R-M3gXY_Hds'}]
# [{'keyword': 'vietnam tourism', 'rank': 1, 'title': 'Vietnam/Popular destinations', 'description': None, 'link': '/destination?q=vietnam+tourism&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwjK8PqP14DaAhWBNo8KHUwfAeMQ7NEBCCwoADAA'}, {'keyword': 'vietnam tourism', 'rank': 2, 'title': 'Vietnam/Popular destinations', 'description': None, 'link': '/destination?q=vietnam+tourism&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwjK8PqP14DaAhWBNo8KHUwfAeMQ7NEBCCwoADAA'}, {'keyword': 'vietnam tourism', 'rank': 3, 'title': 'VIETNAM NATIONAL ADMINISTRATION OF TOURISM', 'description': 'Tong cuc Du lich Viet Nam - Thong tin tong hop - Van ban quan ly nha nuoc.', 'link': 'http://www.vietnamtourism.com/'}, {'keyword': 'vietnam tourism', 'rank': 4, 'title': 'Vietnam 2018: Best of Vietnam Tourism - TripAdvisor', 'description': 'Vietnam Tourism: TripAdvisor has 2329025 reviews of Vietnam Hotels, Attractions, and Restaurants making it your best Vietnam resource.', 'link': 'https://www.tripadvisor.com/Tourism-g293921-Vietnam-Vacations.html'}, {'keyword': 'vietnam tourism', 'rank': 5, 'title': 'Vietnam Tourism, Tourist Places Vietnam, Vietnam Tourism Packages', 'description': 'Vietnam Tourism - Information about tourist places in Vietnam, events & activities, map, attractions in Vietnam. Book Vietnam tourism packages at MakeMyTrip.com.', 'link': 'https://www.makemytrip.com/holidays-international/vietnam-tourism.html'}, {'keyword': 'vietnam tourism', 'rank': 6, 'title': 'Vietnam Tourism (2018): Best of Vietnam - TripAdvisor', 'description': 'Vietnam Tourism: TripAdvisor has 23,29025 reviews of Vietnam Hotels, Attractions, and Restaurants making it your best Vietnam Tourism resource.', 'link': 'https://www.tripadvisor.in/Tourism-g293921-Vietnam-Vacations.html'}, {'keyword': 'vietnam tourism', 'rank': 7, 'title': 'Tourism in Vietnam - Wikipedia', 'description': 'Tourism in Vietnam is a component of the modern Vietnamese economy. In 2012, Vietnam received more than 6.8 million international arrivals, up from 2.1 million in the year 2000. The annual increase represented a rebound from a decline in 2008 Great Recession. The Vietnam National Administration of Tourism is\xa0...', 'link': 'https://en.wikipedia.org/wiki/Tourism_in_Vietnam'}, {'keyword': 'vietnam tourism', 'rank': 8, 'title': 'Vietnam Tourism, Tourist Places in Vietnam, Vietnam Tour and Travel ...', 'description': 'Vietnam Tourism - Get complete information about popular tourist destinations in Vietnam, must visit places in Vietnam, Vietnam tourism packages, best time to visit, map, events, Vietnam culture and food, best attractions in Vietnam, activities and nightlife in Vietnam.', 'link': 'https://www.yatra.com/international-tourism/vietnam'}, {'keyword': 'vietnam tourism', 'rank': 9, 'title': 'Vietnam Tourism > Travel Guide, Places to visit, Tours and Packages', 'description': 'Get the best Information about Vietnam Tourism. Get travel guides and plan your trip to Vietnam with places to visit, sightseeing, hotels, and reviews by other travellers.', 'link': 'https://www.holidify.com/country/vietnam/'}, {'keyword': 'vietnam tourism', 'rank': 10, 'title': 'Vietnam travel - Lonely Planet', 'description': 'Explore Vietnam holidays and discover the best time and places to visit. | A land of staggering natural beauty and cultural complexities, of dynamic megacities and hill-tribe villages, Vietnam is both exotic and compelling.', 'link': 'https://www.lonelyplanet.com/vietnam'}, {'keyword': 'vietnam tourism', 'rank': 11, 'title': 'Vietnam - Amazing destination, Vietnam Tours 2015 - 2016, Vietnam ...', 'description': 'Discover Amazing Vietnam with TripAsean Tour, please visit our web: http://tripasean.com/ to get more ...', 'link': 'https://www.youtube.com/watch?v=R-M3gXY_Hds'}]
# [{'keyword': 'vietnam tourism', 'rank': 1, 'title': 'Vietnam/Popular destinations', 'description': None, 'link': '/destination?q=vietnam+tourism&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwjK8PqP14DaAhWBNo8KHUwfAeMQ7NEBCCwoADAA'}, {'keyword': 'vietnam tourism', 'rank': 2, 'title': 'Vietnam/Popular destinations', 'description': None, 'link': '/destination?q=vietnam+tourism&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwjK8PqP14DaAhWBNo8KHUwfAeMQ7NEBCCwoADAA'}, {'keyword': 'vietnam tourism', 'rank': 3, 'title': 'VIETNAM NATIONAL ADMINISTRATION OF TOURISM', 'description': 'Tong cuc Du lich Viet Nam - Thong tin tong hop - Van ban quan ly nha nuoc.', 'link': 'http://www.vietnamtourism.com/'}, {'keyword': 'vietnam tourism', 'rank': 4, 'title': 'Vietnam 2018: Best of Vietnam Tourism - TripAdvisor', 'description': 'Vietnam Tourism: TripAdvisor has 2329025 reviews of Vietnam Hotels, Attractions, and Restaurants making it your best Vietnam resource.', 'link': 'https://www.tripadvisor.com/Tourism-g293921-Vietnam-Vacations.html'}, {'keyword': 'vietnam tourism', 'rank': 5, 'title': 'Vietnam Tourism, Tourist Places Vietnam, Vietnam Tourism Packages', 'description': 'Vietnam Tourism - Information about tourist places in Vietnam, events & activities, map, attractions in Vietnam. Book Vietnam tourism packages at MakeMyTrip.com.', 'link': 'https://www.makemytrip.com/holidays-international/vietnam-tourism.html'}, {'keyword': 'vietnam tourism', 'rank': 6, 'title': 'Vietnam Tourism (2018): Best of Vietnam - TripAdvisor', 'description': 'Vietnam Tourism: TripAdvisor has 23,29025 reviews of Vietnam Hotels, Attractions, and Restaurants making it your best Vietnam Tourism resource.', 'link': 'https://www.tripadvisor.in/Tourism-g293921-Vietnam-Vacations.html'}, {'keyword': 'vietnam tourism', 'rank': 7, 'title': 'Tourism in Vietnam - Wikipedia', 'description': 'Tourism in Vietnam is a component of the modern Vietnamese economy. In 2012, Vietnam received more than 6.8 million international arrivals, up from 2.1 million in the year 2000. The annual increase represented a rebound from a decline in 2008 Great Recession. The Vietnam National Administration of Tourism is\xa0...', 'link': 'https://en.wikipedia.org/wiki/Tourism_in_Vietnam'}, {'keyword': 'vietnam tourism', 'rank': 8, 'title': 'Vietnam Tourism, Tourist Places in Vietnam, Vietnam Tour and Travel ...', 'description': 'Vietnam Tourism - Get complete information about popular tourist destinations in Vietnam, must visit places in Vietnam, Vietnam tourism packages, best time to visit, map, events, Vietnam culture and food, best attractions in Vietnam, activities and nightlife in Vietnam.', 'link': 'https://www.yatra.com/international-tourism/vietnam'}, {'keyword': 'vietnam tourism', 'rank': 9, 'title': 'Vietnam Tourism > Travel Guide, Places to visit, Tours and Packages', 'description': 'Get the best Information about Vietnam Tourism. Get travel guides and plan your trip to Vietnam with places to visit, sightseeing, hotels, and reviews by other travellers.', 'link': 'https://www.holidify.com/country/vietnam/'}, {'keyword': 'vietnam tourism', 'rank': 10, 'title': 'Vietnam travel - Lonely Planet', 'description': 'Explore Vietnam holidays and discover the best time and places to visit. | A land of staggering natural beauty and cultural complexities, of dynamic megacities and hill-tribe villages, Vietnam is both exotic and compelling.', 'link': 'https://www.lonelyplanet.com/vietnam'}, {'keyword': 'vietnam tourism', 'rank': 11, 'title': 'Vietnam - Amazing destination, Vietnam Tours 2015 - 2016, Vietnam ...', 'description': 'Discover Amazing Vietnam with TripAsean Tour, please visit our web: http://tripasean.com/ to get more ...', 'link': 'https://www.youtube.com/watch?v=R-M3gXY_Hds'}]
# [{'keyword': 'vietnam tourism', 'rank': 1, 'title': 'Vietnam/Popular destinations', 'description': None, 'link': '/destination?q=vietnam+tourism&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwjK8PqP14DaAhWBNo8KHUwfAeMQ7NEBCCwoADAA'}, {'keyword': 'vietnam tourism', 'rank': 2, 'title': 'Vietnam/Popular destinations', 'description': None, 'link': '/destination?q=vietnam+tourism&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwjK8PqP14DaAhWBNo8KHUwfAeMQ7NEBCCwoADAA'}, {'keyword': 'vietnam tourism', 'rank': 3, 'title': 'VIETNAM NATIONAL ADMINISTRATION OF TOURISM', 'description': 'Tong cuc Du lich Viet Nam - Thong tin tong hop - Van ban quan ly nha nuoc.', 'link': 'http://www.vietnamtourism.com/'}, {'keyword': 'vietnam tourism', 'rank': 4, 'title': 'Vietnam 2018: Best of Vietnam Tourism - TripAdvisor', 'description': 'Vietnam Tourism: TripAdvisor has 2329025 reviews of Vietnam Hotels, Attractions, and Restaurants making it your best Vietnam resource.', 'link': 'https://www.tripadvisor.com/Tourism-g293921-Vietnam-Vacations.html'}, {'keyword': 'vietnam tourism', 'rank': 5, 'title': 'Vietnam Tourism, Tourist Places Vietnam, Vietnam Tourism Packages', 'description': 'Vietnam Tourism - Information about tourist places in Vietnam, events & activities, map, attractions in Vietnam. Book Vietnam tourism packages at MakeMyTrip.com.', 'link': 'https://www.makemytrip.com/holidays-international/vietnam-tourism.html'}, {'keyword': 'vietnam tourism', 'rank': 6, 'title': 'Vietnam Tourism (2018): Best of Vietnam - TripAdvisor', 'description': 'Vietnam Tourism: TripAdvisor has 23,29025 reviews of Vietnam Hotels, Attractions, and Restaurants making it your best Vietnam Tourism resource.', 'link': 'https://www.tripadvisor.in/Tourism-g293921-Vietnam-Vacations.html'}, {'keyword': 'vietnam tourism', 'rank': 7, 'title': 'Tourism in Vietnam - Wikipedia', 'description': 'Tourism in Vietnam is a component of the modern Vietnamese economy. In 2012, Vietnam received more than 6.8 million international arrivals, up from 2.1 million in the year 2000. The annual increase represented a rebound from a decline in 2008 Great Recession. The Vietnam National Administration of Tourism is\xa0...', 'link': 'https://en.wikipedia.org/wiki/Tourism_in_Vietnam'}, {'keyword': 'vietnam tourism', 'rank': 8, 'title': 'Vietnam Tourism, Tourist Places in Vietnam, Vietnam Tour and Travel ...', 'description': 'Vietnam Tourism - Get complete information about popular tourist destinations in Vietnam, must visit places in Vietnam, Vietnam tourism packages, best time to visit, map, events, Vietnam culture and food, best attractions in Vietnam, activities and nightlife in Vietnam.', 'link': 'https://www.yatra.com/international-tourism/vietnam'}, {'keyword': 'vietnam tourism', 'rank': 9, 'title': 'Vietnam Tourism > Travel Guide, Places to visit, Tours and Packages', 'description': 'Get the best Information about Vietnam Tourism. Get travel guides and plan your trip to Vietnam with places to visit, sightseeing, hotels, and reviews by other travellers.', 'link': 'https://www.holidify.com/country/vietnam/'}, {'keyword': 'vietnam tourism', 'rank': 10, 'title': 'Vietnam travel - Lonely Planet', 'description': 'Explore Vietnam holidays and discover the best time and places to visit. | A land of staggering natural beauty and cultural complexities, of dynamic megacities and hill-tribe villages, Vietnam is both exotic and compelling.', 'link': 'https://www.lonelyplanet.com/vietnam'}, {'keyword': 'vietnam tourism', 'rank': 11, 'title': 'Vietnam - Amazing destination, Vietnam Tours 2015 - 2016, Vietnam ...', 'description': 'Discover Amazing Vietnam with TripAsean Tour, please visit our web: http://tripasean.com/ to get more ...', 'link': 'https://www.youtube.com/watch?v=R-M3gXY_Hds'}]
# [{'keyword': 'vietnam tourism', 'rank': 1, 'title': 'Vietnam/Popular destinations', 'description': None, 'link': '/destination?q=vietnam+tourism&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwjK8PqP14DaAhWBNo8KHUwfAeMQ7NEBCCwoADAA'}, {'keyword': 'vietnam tourism', 'rank': 2, 'title': 'Vietnam/Popular destinations', 'description': None, 'link': '/destination?q=vietnam+tourism&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwjK8PqP14DaAhWBNo8KHUwfAeMQ7NEBCCwoADAA'}, {'keyword': 'vietnam tourism', 'rank': 3, 'title': 'VIETNAM NATIONAL ADMINISTRATION OF TOURISM', 'description': 'Tong cuc Du lich Viet Nam - Thong tin tong hop - Van ban quan ly nha nuoc.', 'link': 'http://www.vietnamtourism.com/'}, {'keyword': 'vietnam tourism', 'rank': 4, 'title': 'Vietnam 2018: Best of Vietnam Tourism - TripAdvisor', 'description': 'Vietnam Tourism: TripAdvisor has 2329025 reviews of Vietnam Hotels, Attractions, and Restaurants making it your best Vietnam resource.', 'link': 'https://www.tripadvisor.com/Tourism-g293921-Vietnam-Vacations.html'}, {'keyword': 'vietnam tourism', 'rank': 5, 'title': 'Vietnam Tourism, Tourist Places Vietnam, Vietnam Tourism Packages', 'description': 'Vietnam Tourism - Information about tourist places in Vietnam, events & activities, map, attractions in Vietnam. Book Vietnam tourism packages at MakeMyTrip.com.', 'link': 'https://www.makemytrip.com/holidays-international/vietnam-tourism.html'}, {'keyword': 'vietnam tourism', 'rank': 6, 'title': 'Vietnam Tourism (2018): Best of Vietnam - TripAdvisor', 'description': 'Vietnam Tourism: TripAdvisor has 23,29025 reviews of Vietnam Hotels, Attractions, and Restaurants making it your best Vietnam Tourism resource.', 'link': 'https://www.tripadvisor.in/Tourism-g293921-Vietnam-Vacations.html'}, {'keyword': 'vietnam tourism', 'rank': 7, 'title': 'Tourism in Vietnam - Wikipedia', 'description': 'Tourism in Vietnam is a component of the modern Vietnamese economy. In 2012, Vietnam received more than 6.8 million international arrivals, up from 2.1 million in the year 2000. The annual increase represented a rebound from a decline in 2008 Great Recession. The Vietnam National Administration of Tourism is\xa0...', 'link': 'https://en.wikipedia.org/wiki/Tourism_in_Vietnam'}, {'keyword': 'vietnam tourism', 'rank': 8, 'title': 'Vietnam Tourism, Tourist Places in Vietnam, Vietnam Tour and Travel ...', 'description': 'Vietnam Tourism - Get complete information about popular tourist destinations in Vietnam, must visit places in Vietnam, Vietnam tourism packages, best time to visit, map, events, Vietnam culture and food, best attractions in Vietnam, activities and nightlife in Vietnam.', 'link': 'https://www.yatra.com/international-tourism/vietnam'}, {'keyword': 'vietnam tourism', 'rank': 9, 'title': 'Vietnam Tourism > Travel Guide, Places to visit, Tours and Packages', 'description': 'Get the best Information about Vietnam Tourism. Get travel guides and plan your trip to Vietnam with places to visit, sightseeing, hotels, and reviews by other travellers.', 'link': 'https://www.holidify.com/country/vietnam/'}, {'keyword': 'vietnam tourism', 'rank': 10, 'title': 'Vietnam travel - Lonely Planet', 'description': 'Explore Vietnam holidays and discover the best time and places to visit. | A land of staggering natural beauty and cultural complexities, of dynamic megacities and hill-tribe villages, Vietnam is both exotic and compelling.', 'link': 'https://www.lonelyplanet.com/vietnam'}, {'keyword': 'vietnam tourism', 'rank': 11, 'title': 'Vietnam - Amazing destination, Vietnam Tours 2015 - 2016, Vietnam ...', 'description': 'Discover Amazing Vietnam with TripAsean Tour, please visit our web: http://tripasean.com/ to get more ...', 'link': 'https://www.youtube.com/watch?v=R-M3gXY_Hds'}]
# [{'keyword': 'vietnam tourism', 'rank': 1, 'title': 'Vietnam/Popular destinations', 'description': None, 'link': '/destination?q=vietnam+tourism&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwjK8PqP14DaAhWBNo8KHUwfAeMQ7NEBCCwoADAA'}, {'keyword': 'vietnam tourism', 'rank': 2, 'title': 'Vietnam/Popular destinations', 'description': None, 'link': '/destination?q=vietnam+tourism&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwjK8PqP14DaAhWBNo8KHUwfAeMQ7NEBCCwoADAA'}, {'keyword': 'vietnam tourism', 'rank': 3, 'title': 'VIETNAM NATIONAL ADMINISTRATION OF TOURISM', 'description': 'Tong cuc Du lich Viet Nam - Thong tin tong hop - Van ban quan ly nha nuoc.', 'link': 'http://www.vietnamtourism.com/'}, {'keyword': 'vietnam tourism', 'rank': 4, 'title': 'Vietnam 2018: Best of Vietnam Tourism - TripAdvisor', 'description': 'Vietnam Tourism: TripAdvisor has 2329025 reviews of Vietnam Hotels, Attractions, and Restaurants making it your best Vietnam resource.', 'link': 'https://www.tripadvisor.com/Tourism-g293921-Vietnam-Vacations.html'}, {'keyword': 'vietnam tourism', 'rank': 5, 'title': 'Vietnam Tourism, Tourist Places Vietnam, Vietnam Tourism Packages', 'description': 'Vietnam Tourism - Information about tourist places in Vietnam, events & activities, map, attractions in Vietnam. Book Vietnam tourism packages at MakeMyTrip.com.', 'link': 'https://www.makemytrip.com/holidays-international/vietnam-tourism.html'}, {'keyword': 'vietnam tourism', 'rank': 6, 'title': 'Vietnam Tourism (2018): Best of Vietnam - TripAdvisor', 'description': 'Vietnam Tourism: TripAdvisor has 23,29025 reviews of Vietnam Hotels, Attractions, and Restaurants making it your best Vietnam Tourism resource.', 'link': 'https://www.tripadvisor.in/Tourism-g293921-Vietnam-Vacations.html'}, {'keyword': 'vietnam tourism', 'rank': 7, 'title': 'Tourism in Vietnam - Wikipedia', 'description': 'Tourism in Vietnam is a component of the modern Vietnamese economy. In 2012, Vietnam received more than 6.8 million international arrivals, up from 2.1 million in the year 2000. The annual increase represented a rebound from a decline in 2008 Great Recession. The Vietnam National Administration of Tourism is\xa0...', 'link': 'https://en.wikipedia.org/wiki/Tourism_in_Vietnam'}, {'keyword': 'vietnam tourism', 'rank': 8, 'title': 'Vietnam Tourism, Tourist Places in Vietnam, Vietnam Tour and Travel ...', 'description': 'Vietnam Tourism - Get complete information about popular tourist destinations in Vietnam, must visit places in Vietnam, Vietnam tourism packages, best time to visit, map, events, Vietnam culture and food, best attractions in Vietnam, activities and nightlife in Vietnam.', 'link': 'https://www.yatra.com/international-tourism/vietnam'}, {'keyword': 'vietnam tourism', 'rank': 9, 'title': 'Vietnam Tourism > Travel Guide, Places to visit, Tours and Packages', 'description': 'Get the best Information about Vietnam Tourism. Get travel guides and plan your trip to Vietnam with places to visit, sightseeing, hotels, and reviews by other travellers.', 'link': 'https://www.holidify.com/country/vietnam/'}, {'keyword': 'vietnam tourism', 'rank': 10, 'title': 'Vietnam travel - Lonely Planet', 'description': 'Explore Vietnam holidays and discover the best time and places to visit. | A land of staggering natural beauty and cultural complexities, of dynamic megacities and hill-tribe villages, Vietnam is both exotic and compelling.', 'link': 'https://www.lonelyplanet.com/vietnam'}, {'keyword': 'vietnam tourism', 'rank': 11, 'title': 'Vietnam - Amazing destination, Vietnam Tours 2015 - 2016, Vietnam ...', 'description': 'Discover Amazing Vietnam with TripAsean Tour, please visit our web: http://tripasean.com/ to get more ...', 'link': 'https://www.youtube.com/watch?v=R-M3gXY_Hds'}]
# [{'keyword': 'vietnam travel', 'rank': 1, 'title': 'Vietnam/Popular destinations', 'description': None, 'link': '/destination?q=vietnam+travel&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwja3pyR14DaAhVK6Y8KHVC5DEAQ7NEBCDAoADAA'}, {'keyword': 'vietnam travel', 'rank': 2, 'title': 'Vietnam/Popular destinations', 'description': None, 'link': '/destination?q=vietnam+travel&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwja3pyR14DaAhVK6Y8KHVC5DEAQ7NEBCDAoADAA'}, {'keyword': 'vietnam travel', 'rank': 3, 'title': '25 THINGS TO KNOW BEFORE TRAVELING IN VIETNAM - The ...', 'description': 'Jan 19, 2014 - Yes, a “backpacker trail” exists in Vietnam and it is generally: Hanoi – Ha Long Bay – (maybe) Ninh Binh – Hue – (maybe) Da Nang – Hoi An – Nha Trang – Mui Ne – Ho Chi Minh City. I love all these places, but this is where you will encounter other tourists (for better or worse), and be treated most like a tourist.', 'link': 'http://thehungrysuitcase.com/25-things-to-know-before-traveling-in-vietnam/'}, {'keyword': 'vietnam travel', 'rank': 4, 'title': 'Vietnam travel - Lonely Planet', 'description': 'A land of staggering natural beauty and cultural complexities, of dynamic megacities and hill-tribe villages, Vietnam is both exotic and compelling. ... Start exploring Vietnam with Lonely Planet’s video guide to getting around…. ... Lonely Planet Local James Pham has lived in Ho Chi ...', 'link': 'https://www.lonelyplanet.com/vietnam'}, {'keyword': 'vietnam travel', 'rank': 5, 'title': 'Vietnam Tips And Tricks: 26 Key Things To Know Before Your Trip', 'description': 'Oct 26, 2017 - Tours to the floating markets in Mekong Delta are some of the most popular. And some of the most problematic too. You can find all kinds of tours to some of the most popular places in Vietnam such as overnight stay in the Mekong Delta, a convenient Cu Chi Tunnels tour or a romantic cruise in Halong Bay.', 'link': 'https://www.geekyexplorer.com/things-to-know-vietnam-tips-tricks/'}, {'keyword': 'vietnam travel', 'rank': 6, 'title': 'Vietnam Packages – Book Vietnam Holiday Tour Packages at ...', 'description': 'Vietnam Packages - Best offers on Vietnam vacation tours & travel packages at MakeMyTrip. Click to book customized Vietnam packages & get exciting deals for Vietnam holiday packages.', 'link': 'https://www.makemytrip.com/holidays-international/vietnam-vacation-tour-packages.html'}, {'keyword': 'vietnam travel', 'rank': 7, 'title': 'Vietnam Travel Guide - Everything You Need to Know About Vietnam', 'description': "Vietnam is one of Southeast Asia's most beautiful countries, attracting travellers to its lush mountains, bustling cities and golden sand beaches. Despite rapid modernisation in Vietnam's urban centres of Hanoi and Ho Chi Minh, time-honoured traditions remain intact amongst the locals.", 'link': 'http://www.vietnam-guide.com/'}, {'keyword': 'vietnam travel', 'rank': 8, 'title': 'Vietnam: Vietnam travel tips - TripAdvisor', 'description': 'Inside Vietnam: Vietnam travel tips - Before you visit Vietnam, visit TripAdvisor for the latest info and advice, written for travellers by travellers.', 'link': 'https://www.tripadvisor.in/Travel-g293921-c21018/Vietnam:Vietnam.Travel.Tips.html'}, {'keyword': 'vietnam travel', 'rank': 9, 'title': "Things to do in Vietnam: readers' travel tips | Travel | The Guardian", 'description': "Nov 17, 2016 - Vietnam is a food lover's paradise, with countless tasty and affordable options, but the sheer amount of things and places to eat, especially in the big cities, can be overwhelming. Hanoi was the culinary highlight for me and a tour with a local guide is the perfect way to sample a wide selection in a relatively\xa0...", 'link': 'https://www.theguardian.com/travel/2016/nov/17/things-to-do-in-vietnam-beaches-food-hanoi-ho-chi-minh-city'}, {'keyword': 'vietnam travel', 'rank': 10, 'title': '5 Ways To Travel Smarter In Vietnam, And Have Stories To Tell Back ...', 'descrip ...
# ...
# [{'keyword': 'vietnam vaccation', 'rank': 1, 'title': 'Vietnam/Popular destinations', 'description': None, 'link': '/destination?q=vietnam+vacation&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwiXycGS14DaAhXILo8KHYLhCaIQ7NEBCEMoADAA'}, {'keyword': 'vietnam vaccation', 'rank': 2, 'title': 'Vietnam/Popular destinations', 'description': None, 'link': '/destination?q=vietnam+vacation&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwiXycGS14DaAhXILo8KHYLhCaIQ7NEBCEMoADAA'}, {'keyword': 'vietnam vaccation', 'rank': 3, 'title': 'The Best Vietnam Vacation Packages 2018 - TripAdvisor', 'description': "Want to book a vacation to Vietnam? Whether you're off for a romantic vacation, family trip, or an all-inclusive holiday, Vietnam vacation packages on TripAdvisor make planning your trip simple and affordable. Find the perfect vacation package for Vietnam on TripAdvisor by ...", 'link': 'https://www.tripadvisor.com/Vacation_Packages-g293921-Vietnam-Vacations.html'}, {'keyword': 'vietnam vaccation', 'rank': 4, 'title': 'Vietnam 2018: Best of Vietnam Tourism - TripAdvisor', 'description': 'Vietnam Tourism: TripAdvisor has 2329025 reviews of Vietnam Hotels, Attractions, and Restaurants making it your best Vietnam resource.', 'link': 'https://www.tripadvisor.com/Tourism-g293921-Vietnam-Vacations.html'}, {'keyword': 'vietnam vaccation', 'rank': 5, 'title': 'Vietnam travel - Lonely Planet', 'description': 'A land of staggering natural beauty and cultural complexities, of dynamic megacities and hill-tribe villages, Vietnam is both exotic and compelling. ... Start exploring Vietnam with Lonely Planet’s video guide to getting around…. ... Lonely Planet Local James Pham has lived in Ho Chi ...', 'link': 'https://www.lonelyplanet.com/vietnam'}, {'keyword': 'vietnam vaccation', 'rank': 6, 'title': 'The Best Vietnam Vacation Packages 2018 C$52: Your Trip, Your ...', 'description': 'Book your trip in Vietnam and save with Expedia! Choose from thousands of great holiday deals to Vietnam.', 'link': 'https://www.expedia.ca/Vietnam.d194.Destination-Travel-Guides'}, {'keyword': 'vietnam vaccation', 'rank': 7, 'title': 'Vietnam Tours & Vacation Packages 2018-2019 | Zicasso', 'description': 'Zicasso: Best customized tours and vacation packages by top Vietnam specialists. TRAVEL+LEISURE "Best Travel Websites" award.', 'link': 'https://www.zicasso.com/luxury-tours/vietnam/vacation-package-travel-agency'}, {'keyword': 'vietnam vaccation', 'rank': 8, 'title': 'Vietnam Packages – Book Vietnam Holiday Tour Packages at ...', 'description': 'Vietnam Packages - Best offers on Vietnam vacation tours & travel packages at MakeMyTrip. Click to book customized Vietnam packages & get exciting deals for Vietnam holiday packages.', 'link': 'https://www.makemytrip.com/holidays-international/vietnam-vacation-tour-packages.html'}, {'keyword': 'vietnam vaccation', 'rank': 9, 'title': '25 THINGS TO KNOW BEFORE TRAVELING IN VIETNAM - The ...', 'description': 'Jan 19, 2014 - Thailand enjoys a 50% return rate for foreign tourists. In contrast, Vietnam only pulls back 5% of visitors. Personally, I feel that Vietnam walks all over Thailand in almost every travel category except beaches. So, why do so many people have such bad experiences and never return to Vietnam? I hope the list\xa0...', 'link': 'http://thehungrysuitcase.com/25-things-to-know-before-traveling-in-vietnam/'}, {'keyword': 'vietnam vaccation', 'rank': 10, 'title': 'Vietnam Vacations, Tours & Travel Packages - 2018/19 | Goway', 'description': "Dreaming of a Vietnam vacation? Goway has been customizing Vietnam vacations for 48 years and has the expertise and experience needed to turn your travel dreams into reality. Get a free trip quote and book one of our Vietnam tours today. Let's go globetrotting!", 'link': 'https://www.goway.com/trips/dest/asia/cntry/vietnam/'}, {'keyword': 'vietnam vaccation', 'rank': 11, 'title': 'Vietnam Vacation & Tour Packages 2017 | Viet Fun Tr ...
# [{'keyword': 'vietnam vaccation', 'rank': 1, 'title': 'Vietnam/Popular destinations', 'description': None, 'link': '/destination?q=vietnam+vacation&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwiXycGS14DaAhXILo8KHYLhCaIQ7NEBCEMoADAA'}, {'keyword': 'vietnam vaccation', 'rank': 2, 'title': 'Vietnam/Popular destinations', 'description': None, 'link': '/destination?q=vietnam+vacation&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwiXycGS14DaAhXILo8KHYLhCaIQ7NEBCEMoADAA'}, {'keyword': 'vietnam vaccation', 'rank': 3, 'title': 'The Best Vietnam Vacation Packages 2018 - TripAdvisor', 'description': "Want to book a vacation to Vietnam? Whether you're off for a romantic vacation, family trip, or an all-inclusive holiday, Vietnam vacation packages on TripAdvisor make planning your trip simple and affordable. Find the perfect vacation package for Vietnam on TripAdvisor by ...", 'link': 'https://www.tripadvisor.com/Vacation_Packages-g293921-Vietnam-Vacations.html'}, {'keyword': 'vietnam vaccation', 'rank': 4, 'title': 'Vietnam 2018: Best of Vietnam Tourism - TripAdvisor', 'description': 'Vietnam Tourism: TripAdvisor has 2329025 reviews of Vietnam Hotels, Attractions, and Restaurants making it your best Vietnam resource.', 'link': 'https://www.tripadvisor.com/Tourism-g293921-Vietnam-Vacations.html'}, {'keyword': 'vietnam vaccation', 'rank': 5, 'title': 'Vietnam travel - Lonely Planet', 'description': 'A land of staggering natural beauty and cultural complexities, of dynamic megacities and hill-tribe villages, Vietnam is both exotic and compelling. ... Start exploring Vietnam with Lonely Planet’s video guide to getting around…. ... Lonely Planet Local James Pham has lived in Ho Chi ...', 'link': 'https://www.lonelyplanet.com/vietnam'}, {'keyword': 'vietnam vaccation', 'rank': 6, 'title': 'The Best Vietnam Vacation Packages 2018 C$52: Your Trip, Your ...', 'description': 'Book your trip in Vietnam and save with Expedia! Choose from thousands of great holiday deals to Vietnam.', 'link': 'https://www.expedia.ca/Vietnam.d194.Destination-Travel-Guides'}, {'keyword': 'vietnam vaccation', 'rank': 7, 'title': 'Vietnam Tours & Vacation Packages 2018-2019 | Zicasso', 'description': 'Zicasso: Best customized tours and vacation packages by top Vietnam specialists. TRAVEL+LEISURE "Best Travel Websites" award.', 'link': 'https://www.zicasso.com/luxury-tours/vietnam/vacation-package-travel-agency'}, {'keyword': 'vietnam vaccation', 'rank': 8, 'title': 'Vietnam Packages – Book Vietnam Holiday Tour Packages at ...', 'description': 'Vietnam Packages - Best offers on Vietnam vacation tours & travel packages at MakeMyTrip. Click to book customized Vietnam packages & get exciting deals for Vietnam holiday packages.', 'link': 'https://www.makemytrip.com/holidays-international/vietnam-vacation-tour-packages.html'}, {'keyword': 'vietnam vaccation', 'rank': 9, 'title': '25 THINGS TO KNOW BEFORE TRAVELING IN VIETNAM - The ...', 'description': 'Jan 19, 2014 - Thailand enjoys a 50% return rate for foreign tourists. In contrast, Vietnam only pulls back 5% of visitors. Personally, I feel that Vietnam walks all over Thailand in almost every travel category except beaches. So, why do so many people have such bad experiences and never return to Vietnam? I hope the list\xa0...', 'link': 'http://thehungrysuitcase.com/25-things-to-know-before-traveling-in-vietnam/'}, {'keyword': 'vietnam vaccation', 'rank': 10, 'title': 'Vietnam Vacations, Tours & Travel Packages - 2018/19 | Goway', 'description': "Dreaming of a Vietnam vacation? Goway has been customizing Vietnam vacations for 48 years and has the expertise and experience needed to turn your travel dreams into reality. Get a free trip quote and book one of our Vietnam tours today. Let's go globetrotting!", 'link': 'https://www.goway.com/trips/dest/asia/cntry/vietnam/'}, {'keyword': 'vietnam vaccation', 'rank': 11, 'title': 'Vietnam Vacation & Tour Packages 2017 | Viet Fun Tr ...
# [{'keyword': 'vietnam vaccation', 'rank': 1, 'title': 'Vietnam/Popular destinations', 'description': None, 'link': '/destination?q=vietnam+vacation&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwiXycGS14DaAhXILo8KHYLhCaIQ7NEBCEMoADAA'}, {'keyword': 'vietnam vaccation', 'rank': 2, 'title': 'Vietnam/Popular destinations', 'description': None, 'link': '/destination?q=vietnam+vacation&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwiXycGS14DaAhXILo8KHYLhCaIQ7NEBCEMoADAA'}, {'keyword': 'vietnam vaccation', 'rank': 3, 'title': 'The Best Vietnam Vacation Packages 2018 - TripAdvisor', 'description': "Want to book a vacation to Vietnam? Whether you're off for a romantic vacation, family trip, or an all-inclusive holiday, Vietnam vacation packages on TripAdvisor make planning your trip simple and affordable. Find the perfect vacation package for Vietnam on TripAdvisor by ...", 'link': 'https://www.tripadvisor.com/Vacation_Packages-g293921-Vietnam-Vacations.html'}, {'keyword': 'vietnam vaccation', 'rank': 4, 'title': 'Vietnam 2018: Best of Vietnam Tourism - TripAdvisor', 'description': 'Vietnam Tourism: TripAdvisor has 2329025 reviews of Vietnam Hotels, Attractions, and Restaurants making it your best Vietnam resource.', 'link': 'https://www.tripadvisor.com/Tourism-g293921-Vietnam-Vacations.html'}, {'keyword': 'vietnam vaccation', 'rank': 5, 'title': 'Vietnam travel - Lonely Planet', 'description': 'A land of staggering natural beauty and cultural complexities, of dynamic megacities and hill-tribe villages, Vietnam is both exotic and compelling. ... Start exploring Vietnam with Lonely Planet’s video guide to getting around…. ... Lonely Planet Local James Pham has lived in Ho Chi ...', 'link': 'https://www.lonelyplanet.com/vietnam'}, {'keyword': 'vietnam vaccation', 'rank': 6, 'title': 'The Best Vietnam Vacation Packages 2018 C$52: Your Trip, Your ...', 'description': 'Book your trip in Vietnam and save with Expedia! Choose from thousands of great holiday deals to Vietnam.', 'link': 'https://www.expedia.ca/Vietnam.d194.Destination-Travel-Guides'}, {'keyword': 'vietnam vaccation', 'rank': 7, 'title': 'Vietnam Tours & Vacation Packages 2018-2019 | Zicasso', 'description': 'Zicasso: Best customized tours and vacation packages by top Vietnam specialists. TRAVEL+LEISURE "Best Travel Websites" award.', 'link': 'https://www.zicasso.com/luxury-tours/vietnam/vacation-package-travel-agency'}, {'keyword': 'vietnam vaccation', 'rank': 8, 'title': 'Vietnam Packages – Book Vietnam Holiday Tour Packages at ...', 'description': 'Vietnam Packages - Best offers on Vietnam vacation tours & travel packages at MakeMyTrip. Click to book customized Vietnam packages & get exciting deals for Vietnam holiday packages.', 'link': 'https://www.makemytrip.com/holidays-international/vietnam-vacation-tour-packages.html'}, {'keyword': 'vietnam vaccation', 'rank': 9, 'title': '25 THINGS TO KNOW BEFORE TRAVELING IN VIETNAM - The ...', 'description': 'Jan 19, 2014 - Thailand enjoys a 50% return rate for foreign tourists. In contrast, Vietnam only pulls back 5% of visitors. Personally, I feel that Vietnam walks all over Thailand in almost every travel category except beaches. So, why do so many people have such bad experiences and never return to Vietnam? I hope the list\xa0...', 'link': 'http://thehungrysuitcase.com/25-things-to-know-before-traveling-in-vietnam/'}, {'keyword': 'vietnam vaccation', 'rank': 10, 'title': 'Vietnam Vacations, Tours & Travel Packages - 2018/19 | Goway', 'description': "Dreaming of a Vietnam vacation? Goway has been customizing Vietnam vacations for 48 years and has the expertise and experience needed to turn your travel dreams into reality. Get a free trip quote and book one of our Vietnam tours today. Let's go globetrotting!", 'link': 'https://www.goway.com/trips/dest/asia/cntry/vietnam/'}, {'keyword': 'vietnam vaccation', 'rank': 11, 'title': 'Vietnam Vacation & Tour Packages 2017 | Viet Fun Tr ...

# %% [markdown]
# ## imporvement
#
# Note: Currently the keywords are just destinations as of now. There needs to be different combinations of keywords that is possible based on the setting
#
# laid back - travel tours
# backpacking - budget
# adventure - less explored
#
# etc.

# %% [markdown]
# ## Filtering the list of links obtained.
#
# this should only pass through a list of URLs that are scrapable

# %%
links # all the scraped links
# links[2].split('.')[1]
# Out:
# ['/destination?q=vietnam+tourism&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwjK8PqP14DaAhWBNo8KHUwfAeMQ7NEBCCwoADAA',
#  '/destination?q=vietnam+tourism&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwjK8PqP14DaAhWBNo8KHUwfAeMQ7NEBCCwoADAA',
#  'http://www.vietnamtourism.com/',
#  'https://www.tripadvisor.com/Tourism-g293921-Vietnam-Vacations.html',
#  'https://www.makemytrip.com/holidays-international/vietnam-tourism.html',
#  'https://www.tripadvisor.in/Tourism-g293921-Vietnam-Vacations.html',
#  'https://en.wikipedia.org/wiki/Tourism_in_Vietnam',
#  'https://www.yatra.com/international-tourism/vietnam',
#  'https://www.holidify.com/country/vietnam/',
#  'https://www.lonelyplanet.com/vietnam',
#  'https://www.youtube.com/watch?v=R-M3gXY_Hds',
#  '/destination?q=vietnam+travel&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwja3pyR14DaAhVK6Y8KHVC5DEAQ7NEBCDAoADAA',
#  '/destination?q=vietnam+travel&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwja3pyR14DaAhVK6Y8KHVC5DEAQ7NEBCDAoADAA',
#  'http://thehungrysuitcase.com/25-things-to-know-before-traveling-in-vietnam/',
#  'https://www.lonelyplanet.com/vietnam',
#  'https://www.geekyexplorer.com/things-to-know-vietnam-tips-tricks/',
#  'https://www.makemytrip.com/holidays-international/vietnam-vacation-tour-packages.html',
#  'http://www.vietnam-guide.com/',
#  'https://www.tripadvisor.in/Travel-g293921-c21018/Vietnam:Vietnam.Travel.Tips.html',
#  'https://www.theguardian.com/travel/2016/nov/17/things-to-do-in-vietnam-beaches-food-hanoi-ho-chi-minh-city',
#  'https://www.forbes.com/sites/ralphjennings/2017/08/01/4-ways-to-travel-smarter-in-vietnam-with-stories-to-tell/',
#  'https://www.nomadicmatt.com/travel-guides/vietnam-travel-tips/',
#  'https://www.travelvietnam.com/',
#  '/destination?q=vietnam+vacation&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwiXycGS14DaAhXILo8KHYLhCaIQ7NEBCEMoADAA',
#  '/destination?q=vietnam+vacation&hl=en&dcr=0&site=search&output=search&dest_mid=/m/01crd5&sa=X&ved=0ahUKEwiXycGS14DaAhXILo8KHYLhCaIQ7NEBCEMoADAA',
#  'https://www.tripadvisor.com/Vacation_Packages-g293921-Vietnam-Vacations.html',
#  'https://www.tripadvisor.com/Tourism-g293921-Vietnam-Vacations.html',
#  'https://www.lonelyplanet.com/vietnam',
#  'https://www.expedia.ca/Vietnam.d194.Destination-Travel-Guides',
#  'https://www.zicasso.com/luxury-tours/vietnam/vacation-package-travel-agency',
#  'https://www.makemytrip.com/holidays-international/vietnam-vacation-tour-packages.html',
#  'http://thehungrysuitcase.com/25-things-to-know-before-traveling-in-vietnam/',
#  'https://www.goway.com/trips/dest/asia/cntry/vietnam/',
#  'https://vietfuntravel.com/vietnam-vacation-packages']

# %%
def filt_useful(e):
    exclude_list= ['youtube', 'dailymotion'] # exlude these websites
    p = [x for x in e if x.startswith('http') and x.split('.')[1] not in exclude_list]
    return p
filtered_links = filt_useful(links)

# %% [markdown]
# ## Function to fetch URLs and return main text
#
# from learn to scrape

# %%
# filters for visible elements dependant on from bs4.element import Comment

from bs4.element import Comment

def tag_visible(element):
    if element.parent.name in ['style', 'script', 'head', 'title', 'meta', '[document]']:
        return False
    if isinstance(element, Comment):
        return False
    return True


def text_from_html(body):
    soup = bs.BeautifulSoup(body, 'html.parser')
    texts = soup.findAll(text=True)
    visible_texts = filter(tag_visible, texts)  
    return u" ".join(t.strip() for t in visible_texts)

# %%
# headers2,headers3,headers4,headers5, o, t = [],[],[],[],[],[]
for i in filtered_links:
    a = text_from_html(i)
    t = a.split(' ')
    o = [w for w in t if len(w)>3 and w.istitle()]    

    
#     r  = requests.get(i,headers=USER_AGENT)
#     soup = bs.BeautifulSoup(r.text,'lxml')
#     t = soup.split(' ')
#     o = [w for w in t if len(w)>3 and w.istitle()]
#     print (soup)
#     for h in soup.find_all('h2'):
#         headers2.append(h.text)
#     for h in soup.find_all('h3'):
#         headers3.append(h.text)
#     for h in soup.find_all('h4'):
#         headers4.append(h.text)
#     for h in soup.find_all('h5'):
#         headers5.append(h.text)

# %%
o

# %%
# headers2
# headers3
# headers4
headers5

# %% [markdown]
# ## Writing to a file

# %%
my_df = pd.DataFrame(data)

my_df.to_csv('my_csv.csv', index=False, header=True) #Header = True adds the header to the file. False doesn't add any.

# %% [markdown]
# Once the resutls are written to the file. Need to understand which ones are the best places to see.

# %% [markdown]
# ### Atlas Obscura
# get_atlas_obs - This function reads atlas obscura for locations
#
# i/p is country

# %%
# url = 'https://www.lonelyplanet.com/vietnam/ho-chi-minh-city/travel-tips-and-articles/how-to-live-like-a-local-in-ho-chi-minh-city/40625c8c-8a11-5710-a052-1479d276bc91'       

def get_atlas_obs(c):
    url='https://www.atlasobscura.com/things-to-do/'+c+'/places'

    r  = requests.get(url)
    soup = bs.BeautifulSoup(r.text,'lxml')

    for div in soup.find_all("section", {"class": "geo-places"}):
    #     print(div.get_text())
        for link in div.find_all('h3'):
            print(link.text)

c = input('What is your destination country?')
get_atlas_obs(c)

# %% [markdown]
# # goetext library

# %%
from geotext import GeoText

# %%
# u = 'https://www.lonelyplanet.com/vietnam/ho-chi-minh-city/travel-tips-and-articles/how-to-live-like-a-local-in-ho-chi-minh-city/40625c8c-8a11-5710-a052-1479d276bc91'
# u = 'https://www.tripadvisor.com/Attractions-g293921-Activities-Vietnam.html'
u = 'http://www.vietnam-guide.com/attractions/top10-attractions.htm'
r  = requests.get(u,headers=USER_AGENT)
soup = bs.BeautifulSoup(r.text,'lxml')
content=''

for div in soup.find_all('p'):
    text = div.get_text()
#     print(len(text))
#     print(text)
    if len(text) > 100:
        content += str(text)

# %%
content

# %%
places = GeoText(content)
print(places.cities)
print(places.countries)
destination = places.country_mentions
print(destination)

# %% [markdown]
# Need to remove the header and footer.
#     Compare with another page on the same website

# %%
from newspaper import Article

# %%
article = Article(u)

# %%
article.download()
article.parse()
article.text

# %%
places = GeoText(article.text)
places.cities
